# %% [markdown]
# # Controller

# %% [markdown]
# This notebook is responsible for integrating all the notebooks present in this project
#
# When executed, this notebook automaticall runs all other notebooks sequantially.

# %%
# Importing important libraries

import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim

#Resizing the Plots
plt.rcParams["figure.figsize"] = (12, 12)

# %%
# Running gui_1.ipynb

# %run ./gui_1.ipynb
# Out:
# C:/7 Sem/CV/Counterfeit-Currency-Detection-using-Image-Processing/data/counterfeit/500/500_f1.jpg
# 1
# Stored 'selectedImage' (bool)
# Stored 'path' (str)
# Stored 'option' (int)

# %%
# The GUI file produces and then stores the variables path and option
# Reading the stored variables

# %store -r selectedImage
# %store -r path
# %store -r option

print('Image selected: ', selectedImage)
print('Path: ', path)
print('Currency type: ', option)
# Out:
# Image selected:  True
# Path:  C:/7 Sem/CV/Counterfeit-Currency-Detection-using-Image-Processing/data/counterfeit/500/500_f1.jpg
# Currency type:  1

# %%
if selectedImage == True:
    if option == 1:                        # For 500 currency note
        # %run ./500_Testing.ipynb
    elif option == 2:                      # For 2000 currency note
        # %run ./2000_Testing.ipynb
# Out:
# Path of input image:  C:/7 Sem/CV/Counterfeit-Currency-Detection-using-Image-Processing/data/counterfeit/500/500_f1.jpg
# ANALYSIS OF FEATURE 1
# ---> Template 1 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 2 :
# SSIM score:  0.2050373775326121
#
# ---> Template 3 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 4 :
# SSIM score:  0.23447550869829753
#
# ---> Template 5 :
# SSIM score:  0.28927421888113336
#
# ---> Template 6 :
# SSIM score:  0.2763645848463934
#
# ---> Template 7 :
# SSIM score:  0.21884956099982017
#
# ---> Template 8 :
# SSIM score:  0.213582862964877
#
# ---> Template 9 :
# SSIM score:  0.21532201729600528
#
# ---> Template 10 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 11 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 12 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 13 :
# SSIM score:  0.21064555978861743
#
# ---> Template 14 :
# SSIM score:  0.20568229949919142
#
# ---> Template 15 :
# SSIM score:  0.2048285650079464
#
# ---> Template 16 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 17 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 18 :
# SSIM score:  0.2614840314690579
#
# ---> Template 19 :
# SSIM score:  0.2368977295463288
#
# ---> Template 20 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 21 :
# SSIM score:  0.21880905959219848
#
# ---> Template 22 :
# SSIM score:  0.256422827326092
#
# ---> Template 23 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 24 :
# SSIM score:  0.2978508943848496
#
# ---> Template 25 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 26 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 27 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 28 :
# SSIM score:  0.2190186856179846
#
# ---> Template 29 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 30 :
# SSIM score:  0.20884396600323182
#
# SSIM score set of Feature 1:  [np.float64(0.2050373775326121), np.float64(0.23447550869829753), np.float64(0.28927421888113336), np.float64(0.2763645848463934), np.float64(0.21884956099982017), np.float64(0.213582862964877), np.float64(0.21532201729600528), np.float64(0.21064555978861743), np.float64(0.20568229949919142), np.float64(0.2048285650079464), np.float64(0.2614840314690579), np.float64(0.2368977295463288), np.float64(0.21880905959219848), np.float64(0.256422827326092), np.float64(0.2978508943848496), np.float64(0.2190186856179846), np.float64(0.20884396600323182)]
#
# Average SSIM of Feature 1:  0.23372880879144928
#
# ANALYSIS OF FEATURE 2
# ---> Template 1 :
# SSIM score:  0.4605447086873678
#
# ---> Template 2 :
# SSIM score:  0.6063964592517413
#
# ---> Template 3 :
# SSIM score:  0.7283382525814585
#
# ---> Template 4 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 5 :
# SSIM score:  0.2124639542043832
#
# ---> Template 6 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 7 :
# SSIM score:  0.3221402350886423
#
# ---> Template 8 :
# SSIM score:  0.526371403306281
#
# ---> Template 9 :
# SSIM score:  0.7143987948984171
#
# ---> Template 10 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 11 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 12 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 13 :
# SSIM score:  0.2548004097250365
#
# ---> Template 14 :
# SSIM score:  0.5322680984766326
#
# ---> Template 15 :
# SSIM score:  0.5765363990821787
#
# ---> Template 16 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 17 :
# SSIM score:  0.193751425179309
#
# ---> Template 18 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 19 :
# SSIM score:  0.345542387183214
#
# ---> Template 20 :
# SSIM score:  0.22036805140799415
#
# ---> Template 21 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 22 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 23 :
# SSIM score:  0.20677180788394053
#
# ---> Template 24 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 25 :
# SSIM score:  0.46431532519861457
#
# ---> Template 26 :
# SSIM score:  0.45092792039572893
#
# ---> Template 27 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 28 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 29 :
# SSIM score:  0.17123233400407678
#
# ---> Template 30 :
# An Error occurred - Homography matrix is of NoneType
# SSIM score set of Feature 2:  [np.float64(0.4605447086873678), np.float64(0.6063964592517413), np.float64(0.7283382525814585), np.float64(0.2124639542043832), np.float64(0.3221402350886423), np.float64(0.526371403306281), np.float64(0.7143987948984171), np.float64(0.2548004097250365), np.float64(0.5322680984766326), np.float64(0.5765363990821787), np.float64(0.193751425179309), np.float64(0.345542387183214), np.float64(0.22036805140799415), np.float64(0.20677180788394053), np.float64(0.46431532519861457), np.float64(0.45092792039572893), np.float64(0.17123233400407678)]
#
# Average SSIM of Feature 2:  0.4110098803855893
#
# ANALYSIS OF FEATURE 3
# ---> Template 1 :
# SSIM score:  0.670964557844046
#
# ---> Template 2 :
# SSIM score:  0.7010748854484755
#
# ---> Template 3 :
# SSIM score:  0.9353702161158343
#
# ---> Template 4 :
# SSIM score:  0.1599692759689201
#
# ---> Template 5 :
# SSIM score:  0.6404499534829229
#
# ---> Template 6 :
# SSIM score:  0.5192867686157328
#
# ---> Template 7 :
# SSIM score:  0.6854767857041258
#
# ---> Template 8 :
# SSIM score:  0.726556479774719
#
# ---> Template 9 :
# SSIM score:  0.9210528377054162
#
# ---> Template 10 :
# SSIM score:  0.1569312457838503
#
# ---> Template 11 :
# SSIM score:  0.6210926944035102
#
# ---> Template 12 :
# SSIM score:  0.4778724393991139
#
# ---> Template 13 :
# SSIM score:  0.6570981870368854
#
# ---> Template 14 :
# SSIM score:  0.5750088725311527
#
# ---> Template 15 :
# SSIM score:  0.8909326268671223
#
# ---> Template 16 :
# SSIM score:  0.16566450568867144
#
# ---> Template 17 :
# SSIM score:  0.5527346666550725
#
# ---> Template 18 :
# SSIM score:  0.4975576653133117
#
# ---> Template 19 :
# SSIM score:  0.15441541829879032
#
# ---> Template 20 :
# SSIM score:  0.12284962057752673
#
# ---> Template 21 :
# SSIM score:  0.15023734153564622
#
# ---> Template 22 :
# SSIM score:  0.2272477160643753
#
# ---> Template 23 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 24 :
# SSIM score:  0.15014499534594525
#
# ---> Template 25 :
# SSIM score:  0.09988133409323144
#
# ---> Template 26 :
# SSIM score:  0.7112237840089239
#
# ---> Template 27 :
# SSIM score:  0.8367101570479267
#
# ---> Template 28 :
# SSIM score:  0.14476750717701745
#
# ---> Template 29 :
# SSIM score:  0.11668065449128333
#
# ---> Template 30 :
# SSIM score:  0.1307820302967339
#
# SSIM score set of Feature 3:  [np.float64(0.670964557844046), np.float64(0.7010748854484755), np.float64(0.9353702161158343), np.float64(0.1599692759689201), np.float64(0.6404499534829229), np.float64(0.5192867686157328), np.float64(0.6854767857041258), np.float64(0.726556479774719), np.float64(0.9210528377054162), np.float64(0.1569312457838503), np.float64(0.6210926944035102), np.float64(0.4778724393991139), np.float64(0.6570981870368854), np.float64(0.5750088725311527), np.float64(0.8909326268671223), np.float64(0.16566450568867144), np.float64(0.5527346666550725), np.float64(0.4975576653133117), np.float64(0.15441541829879032), np.float64(0.12284962057752673), np.float64(0.15023734153564622), np.float64(0.2272477160643753), np.float64(0.15014499534594525), np.float64(0.09988133409323144), np.float64(0.7112237840089239), np.float64(0.8367101570479267), np.float64(0.14476750717701745), np.float64(0.11668065449128333), np.float64(0.1307820302967339)]
#
# Average SSIM of Feature 3:  0.46207018011297535
#
# ANALYSIS OF FEATURE 4
# ---> Template 1 :
# SSIM score:  0.41295743869451135
#
# ---> Template 2 :
# SSIM score:  0.42723471560729914
#
# ---> Template 3 :
# SSIM score:  0.7964979642895064
#
# ---> Template 4 :
# SSIM score:  0.5801856070072388
#
# ---> Template 5 :
# SSIM score:  0.5028946538283856
#
# ---> Template 6 :
# SSIM score:  0.5551777947914968
#
# ---> Template 7 :
# SSIM score:  0.4573819687777643
#
# ---> Template 8 :
# SSIM score:  0.5143854328676881
#
# ---> Template 9 :
# SSIM score:  0.7119665113395395
#
# ---> Template 10 :
# SSIM score:  0.6081094319877541
#
# ---> Template 11 :
# SSIM score:  0.48200543861476947
#
# ---> Template 12 :
# SSIM score:  0.5110968338436668
#
# ---> Template 13 :
# SSIM score:  0.12375443789748251
#
# ---> Template 14 :
# SSIM score:  0.5783358739305187
#
# ---> Template 15 :
# SSIM score:  0.9041978944519672
#
# ---> Template 16 :
# SSIM score:  0.5720626718886851
#
# ---> Template 17 :
# SSIM score:  0.4335376480461741
#
# ---> Template 18 :
# SSIM score:  0.5342771109214817
#
# ---> Template 19 :
# SSIM score:  0.18276387357395374
#
# ---> Template 20 :
# SSIM score:  0.12848896399734305
#
# ---> Template 21 :
# SSIM score:  0.1615210681839794
#
# ---> Template 22 :
# SSIM score:  0.19068157770015196
#
# ---> Template 23 :
# SSIM score:  0.18622889930220357
#
# ---> Template 24 :
# SSIM score:  0.22413396735575558
#
# ---> Template 25 :
# SSIM score:  0.5443760362154584
#
# ---> Template 26 :
# SSIM score:  0.6700682428390005
#
# ---> Template 27 :
# SSIM score:  0.11147973183811273
#
# ---> Template 28 :
# SSIM score:  0.5951908766041168
#
# ---> Template 29 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 30 :
# SSIM score:  0.16827330349177394
#
# SSIM score set of Feature 4:  [np.float64(0.41295743869451135), np.float64(0.42723471560729914), np.float64(0.7964979642895064), np.float64(0.5801856070072388), np.float64(0.5028946538283856), np.float64(0.5551777947914968), np.float64(0.4573819687777643), np.float64(0.5143854328676881), np.float64(0.7119665113395395), np.float64(0.6081094319877541), np.float64(0.48200543861476947), np.float64(0.5110968338436668), np.float64(0.12375443789748251), np.float64(0.5783358739305187), np.float64(0.9041978944519672), np.float64(0.5720626718886851), np.float64(0.4335376480461741), np.float64(0.5342771109214817), np.float64(0.18276387357395374), np.float64(0.12848896399734305), np.float64(0.1615210681839794), np.float64(0.19068157770015196), np.float64(0.18622889930220357), np.float64(0.22413396735575558), np.float64(0.5443760362154584), np.float64(0.6700682428390005), np.float64(0.11147973183811273), np.float64(0.5951908766041168), np.float64(0.16827330349177394)]
#
# Average SSIM of Feature 4:  0.44376779206509587
#
# ANALYSIS OF FEATURE 5
# ---> Template 1 :
# SSIM score:  0.6128195372446686
#
# ---> Template 2 :
# SSIM score:  0.5580852274605618
#
# ---> Template 3 :
# SSIM score:  0.8976284995463224
#
# ---> Template 4 :
# SSIM score:  0.7160882131534875
#
# ---> Template 5 :
# SSIM score:  0.4969836141796797
#
# ---> Template 6 :
# SSIM score:  0.5649421593940511
#
# ---> Template 7 :
# SSIM score:  0.6492427149197445
#
# ---> Template 8 :
# SSIM score:  0.49762445885882245
#
# ---> Template 9 :
# SSIM score:  0.8856472691172135
#
# ---> Template 10 :
# SSIM score:  0.7089994243691266
#
# ---> Template 11 :
# SSIM score:  0.4937694862304941
#
# ---> Template 12 :
# SSIM score:  0.4406022295512455
#
# ---> Template 13 :
# SSIM score:  0.4851719072619226
#
# ---> Template 14 :
# SSIM score:  0.7809502114119337
#
# ---> Template 15 :
# SSIM score:  0.8656624209681187
#
# ---> Template 16 :
# SSIM score:  0.4372009031601944
#
# ---> Template 17 :
# SSIM score:  0.6664650230629016
#
# ---> Template 18 :
# SSIM score:  0.6328121287321332
#
# ---> Template 19 :
# SSIM score:  0.22980330175840644
#
# ---> Template 20 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 21 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 22 :
# SSIM score:  0.432138035228772
#
# ---> Template 23 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 24 :
# SSIM score:  0.4741675788146858
#
# ---> Template 25 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 26 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 27 :
# SSIM score:  0.8810543452299574
#
# ---> Template 28 :
# SSIM score:  0.6625842990308775
#
# ---> Template 29 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 30 :
# SSIM score:  0.5288076003699888
#
# SSIM score set of Feature 5:  [np.float64(0.6128195372446686), np.float64(0.5580852274605618), np.float64(0.8976284995463224), np.float64(0.7160882131534875), np.float64(0.4969836141796797), np.float64(0.5649421593940511), np.float64(0.6492427149197445), np.float64(0.49762445885882245), np.float64(0.8856472691172135), np.float64(0.7089994243691266), np.float64(0.4937694862304941), np.float64(0.4406022295512455), np.float64(0.4851719072619226), np.float64(0.7809502114119337), np.float64(0.8656624209681187), np.float64(0.4372009031601944), np.float64(0.6664650230629016), np.float64(0.6328121287321332), np.float64(0.22980330175840644), np.float64(0.432138035228772), np.float64(0.4741675788146858), np.float64(0.8810543452299574), np.float64(0.6625842990308775), np.float64(0.5288076003699888)]
#
# Average SSIM of Feature 5:  0.6083021078773047
#
# ANALYSIS OF FEATURE 6
# ---> Template 1 :
# SSIM score:  0.7495608068721487
#
# ---> Template 2 :
# SSIM score:  0.6993287079889684
#
# ---> Template 3 :
# SSIM score:  0.9262475406588052
#
# ---> Template 4 :
# SSIM score:  0.7115556319526086
#
# ---> Template 5 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 6 :
# SSIM score:  0.3621131697823806
#
# ---> Template 7 :
# SSIM score:  0.6851893673270864
#
# ---> Template 8 :
# SSIM score:  0.6164397127947486
#
# ---> Template 9 :
# SSIM score:  0.8250808563220432
#
# ---> Template 10 :
# SSIM score:  0.6203991352891763
#
# ---> Template 11 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 12 :
# SSIM score:  0.18354686754759234
#
# ---> Template 13 :
# SSIM score:  0.5635907491376266
#
# ---> Template 14 :
# SSIM score:  0.5272602221842887
#
# ---> Template 15 :
# SSIM score:  0.8366879660765989
#
# ---> Template 16 :
# SSIM score:  0.6012152057104537
#
# ---> Template 17 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 18 :
# SSIM score:  0.6006652218714535
#
# ---> Template 19 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 20 :
# SSIM score:  0.4461647057709283
#
# ---> Template 21 :
# SSIM score:  0.3629679922998942
#
# ---> Template 22 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 23 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 24 :
# SSIM score:  0.17533988831445285
#
# ---> Template 25 :
# SSIM score:  0.19869812396791262
#
# ---> Template 26 :
# SSIM score:  0.5029187515146653
#
# ---> Template 27 :
# SSIM score:  0.8852272121563296
#
# ---> Template 28 :
# SSIM score:  0.5183567898243017
#
# ---> Template 29 :
# An Error occurred - Homography matrix is of NoneType
# ---> Template 30 :
# SSIM score:  0.17796170049657165
#
# SSIM score set of Feature 6:  [np.float64(0.7495608068721487), np.float64(0.6993287079889684), np.float64(0.9262475406588052), np.float64(0.7115556319526086), np.float64(0.3621131697823806), np.float64(0.6851893673270864), np.float64(0.6164397127947486), np.float64(0.8250808563220432), np.float64(0.6203991352891763), np.float64(0.18354686754759234), np.float64(0.5635907491376266), np.float64(0.5272602221842887), np.float64(0.8366879660765989), np.float64(0.6012152057104537), np.float64(0.6006652218714535), np.float64(0.4461647057709283), np.float64(0.3629679922998942), np.float64(0.17533988831445285), np.float64(0.19869812396791262), np.float64(0.5029187515146653), np.float64(0.8852272121563296), np.float64(0.5183567898243017), np.float64(0.17796170049657165)]
#
# Average SSIM of Feature 6:  0.555500709820045
#
# ANALYSIS OF FEATURE 7
# ---> Template 1 :
# SSIM score:  0.4827527193607608
#
# ---> Template 2 :
# SSIM score:  0.18797264864465238
#
# ---> Template 3 :
# SSIM score:  0.8799559236433734
#
# ---> Template 4 :
# SSIM score:  0.647068142368553
#
# ---> Template 5 :
# SSIM score:  0.6725559904807175
#
# ---> Template 6 :
# SSIM score:  0.2549053702948368
#
# ---> Template 7 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 8 :
# SSIM score:  0.6043194637811505
#
# ---> Template 9 :
# SSIM score:  0.8723337140780452
#
# ---> Template 10 :
# SSIM score:  0.6365921939571545
#
# ---> Template 11 :
# SSIM score:  0.639279917136938
#
# ---> Template 12 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 13 :
# SSIM score:  0.47373945592670985
#
# ---> Template 14 :
# SSIM score:  0.5364828713276174
#
# ---> Template 15 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template 16 :
# SSIM score:  0.5576383658456348
#
# ---> Template 17 :
# SSIM score:  0.6684156567455013
#
# ---> Template 18 :
# SSIM score:  0.5467725047622535
#
# ---> Template 19 :
# SSIM score:  0.2478563844304925
#
# ---> Template 20 :
# SSIM score:  0.18548695903670107
#
# ---> Template 21 :
# Template Discarded- Area of extracted feature is outside permitted range!
# ---> Template
#
# Number of black regions found in each column:
# 3
# 3
# 3
# 3
# 3
# 3
# 16 Erroneous -> discarded
# 18 Erroneous -> discarded
# 19 Erroneous -> discarded
# 19 Erroneous -> discarded
# 24 Erroneous -> discarded
# 22 Erroneous -> discarded
# 17 Erroneous -> discarded
# 18 Erroneous -> discarded
# 16 Erroneous -> discarded
# 12 Erroneous -> discarded
# 14 Erroneous -> discarded
# 18 Erroneous -> discarded
# 17 Erroneous -> discarded
# 18 Erroneous -> discarded
# 18 Erroneous -> discarded
# 17 Erroneous -> discarded
# 15 Erroneous -> discarded
#
# Number of columns examined:  23
# Number of non- erroneous columns found:  6
#
# Average number of black regions is:  3.0
#
# ANALYSIS OF FEATURE 9 : RIGHT BLEED LINES
#
# Number of black regions found in each column:
# 16 Erroneous -> discarded
# 16 Erroneous -> discarded
# 16 Erroneous -> discarded
# 28 Erroneous -> discarded
# 16 Erroneous -> discarded
# 8
# 3
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 3
#
# Number of columns examined:  20
# Number of non- erroneous columns found:  15
#
# Average number of black regions is:  3.466666666666667
#
# ANALYSIS OF FEATURE 10 : NUMBER PANEL
#
# ---> Threshold 1 with Threshold value 95 :
# Unsuccessful!
# ---> Threshold 8 with Threshold value 100 :
# Unsuccessful!
# ---> Threshold 8 with Threshold value 105 :
# Unsuccessful!
# ---> Threshold 8 with Threshold value 110 :
# Unsuccessful!
# ---> Threshold 7 with Threshold value 115 :
# Unsuccessful!
# ---> Threshold 7 with Threshold value 120 :
# Unsuccessful!
# ---> Threshold 7 with Threshold value 125 :
# Unsuccessful!
# ---> Threshold 7 with Threshold value 130 :
# Unsuccessful!
# ---> Threshold 8 with Threshold value 135 :
# Unsuccessful!
# ---> Threshold 7 with Threshold value 140 :
# Unsuccessful!
# ---> Threshold 8 with Threshold value 145 :
# Unsuccessful!
# ---> Threshold 6 with Threshold value 150 :
# Unsuccessful!
# Test Failed!- 9 characters were NOT detected in the serial number panel.
#
# ANALYSIS OF FEATURE 11 : COLOR PROFILE CHECK
#
# Base color ratio: 0.876, Thread shift ratio: 0.016
#
# ANALYSIS OF FEATURE 12 : WATERMARK STRUCTURAL CHECK
#
# Watermark Standard Deviation: 19.442, Edge Density: 0.082
#
#
# RESULT ANALYSIS
#
# Feature 1: Unsuccessful
# Feature 2: Successful
# Feature 3: Successful
# Feature 4: Successful
# Feature 5: Successful
# Feature 6: Successful
# Feature 7: Successful
# Feature 8: Unsuccessful!
# Feature 9: Unsuccessful!
# Feature 10: Unsuccessful!
#
# Result Summary:
# Feature 11: Successful - Base color and security thread profiles verified.
# Feature 12: Successful - Watermark window structural check verified.
#
# Result Summary:
# 8 out of 12 features are VERIFIED!
# Stored 'result_list' (list)
# Stored 'confidence_score' (float)
# Stored 'elapsed_time_ms' (float)

# %%
if selectedImage == True:
    # The above file produces and stores result_list variable
    # Reading the variable
    # %store -r result_list

    # Showing the results
    # The result list variable is a list of lists and each list conatins details about each feature
    for x in result_list:
        if x[0] is not None:            
            plt.imshow(x[0])   # Showing images
            plt.show()

# %%
if selectedImage == True:
# Show output in GUI

    # %run ./gui_2.ipynb
